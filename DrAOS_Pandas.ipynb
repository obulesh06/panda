# %%
import pandas as pd
s = pd.Series([1,3,5,6,8])
print(s)
# Out:
# 0    1
# 1    3
# 2    5
# 3    6
# 4    8
# dtype: int64

# %%
dates = pd.date_range('20200701', periods=6)
print(dates)
# Out:
# DatetimeIndex(['2020-07-01', '2020-07-02', '2020-07-03', '2020-07-04',
#                '2020-07-05', '2020-07-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
import pandas as pd
import numpy as np
data = np.array(['a','b','c','d'])
s = pd.Series(data)
print(s)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
import pandas as pd
import numpy as np
data = np.array(['a','b','c','d'])
s = pd.Series(data,index=[100,101,102,103])
print(s)
# Out:
# 100    a
# 101    b
# 102    c
# 103    d
# dtype: object

# %%
import pandas as pd
import numpy as np
data = {'a' : 0., 'b' : 1., 'c' : 2.}
s = pd.Series(data)
print(s)
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
import pandas as pd
import numpy as np
data = {'a' : 0., 'b' : 1., 'c' : 2.}
s = pd.Series(data,index=['b','c','d','a'])
print(s)
# Out:
# b    1.0
# c    2.0
# d    NaN
# a    0.0
# dtype: float64

# %%
import pandas as pd
import numpy as np
s = pd.Series(5, index=[0, 1, 2, 3])
print(s)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %%
import pandas as pd
s = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])
print(s[:3])
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
import pandas as pd
s = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])
print(s[-3:])
# Out:
# c    3
# d    4
# e    5
# dtype: int64

# %%
import pandas as pd
s = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])
print(s['a'])
# Out:
# 1

# %%
import pandas as pd
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as p
x= p.Series([1,2,3,4], index =[10,20,30,40])
print(x)
L=[ [10,20,30], [100,200,300] ]
y = p.DataFrame(L)
print(y)

K=[['rishi', 10], ['reema', 20], ['banana', 30] ]

M=p.DataFrame(K, index = ['RaW','Col','Ram'], columns=['Name', 'Price'])


print(M)
#print(x[3:])
# Out:
# 10    1
# 20    2
# 30    3
# 40    4
# dtype: int64
#      0    1    2
# 0   10   20   30
# 1  100  200  300
#        Name  Price
# RaW   rishi     10
# Col   reema     20
# Ram  banana     30

# %%
import pandas as PP
P=PP.Series([1,2,3,4], index =[100,200,300,400])
print(P)


X=PP.DataFrame([[100,200,300], [10,20,30]])
print(X.shape)
print(X[0][0])
print(X.T)
#print(X.dim)
print(X.dtypes)
# Out:
# 100    1
# 200    2
# 300    3
# 400    4
# dtype: int64
# (2, 3)
# 100
#      0   1
# 0  100  10
# 1  200  20
# 2  300  30
# 0    int64
# 1    int64
# 2    int64
# dtype: object

# %%
import pandas as pd
data = [ ['obulesh',24] , ['sheshi',12],['Sagar',13]]

df = pd.DataFrame(data,   columns=['Name','Age'])

print(df)
# Out:
#       Name  Age
# 0  obulesh   24
# 1   sheshi   12
# 2    Sagar   13

# %%
import pandas as pd
data = [1,2,3,4,5]
df = pd.DataFrame(data)
print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
import pandas as pd
data = [['Alex',10],['Bob',12],['Clarke',13]]
df = pd.DataFrame(data,columns=['Name','Age'])
print(df)
# Out:
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Clarke   13

# %%
import pandas as pd
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42]}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0    Tom   28
# 1   Jack   34
# 2  Steve   29
# 3  Ricky   42

# %%
import pandas as pd
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df = pd.DataFrame(data)
print(df)
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %%
#changing of index 
import pandas as pd
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df = pd.DataFrame(data, index=['first', 'second'])
print(df)

# %%
import pandas as pd
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df1 = pd.DataFrame(data, index=['first', 'second'], columns=['a', 'b'])
df2 = pd.DataFrame(data, index=['first', 'second'], columns=['a', 'b1'])
print(df1)
print(df2)
# Out:
#         a   b
# first   1   2
# second  5  10
#         a  b1
# first   1 NaN
# second  5 NaN

# %%
import pandas as pd
d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}
df = pd.DataFrame(d)
print(df ['one'])
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64

# %%
#Adding to data with series 
import pandas as pd
d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}
df = pd.DataFrame(d)
print ("Adding a new column by passing as Series:")
df['three']=pd.Series([10,20,30],index=['a','b','c'])
print(df)
print ("Adding a new column using the existing columns in DataFrame:")
df['four']=df['one']+df['three']
print(df)
# Out:
# Adding a new column by passing as Series:
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN
# Adding a new column using the existing columns in DataFrame:
#    one  two  three  four
# a  1.0    1   10.0  11.0
# b  2.0    2   20.0  22.0
# c  3.0    3   30.0  33.0
# d  NaN    4    NaN   NaN

# %%
import pandas as pd
d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']), 
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd']), 
   'three' : pd.Series([10,20,30], index=['a','b','c'])}
df = pd.DataFrame(d)
print ("Our dataframe is:")
print(df)
print ("Deleting the first column using DEL function:")
del df['one']
print(df)
print ("Deleting another column using POP function:")
df.pop('two')
print(df)
# Out:
# Our dataframe is:
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN
# Deleting the first column using DEL function:
#    two  three
# a    1   10.0
# b    2   20.0
# c    3   30.0
# d    4    NaN
# Deleting another column using POP function:
#    three
# a   10.0
# b   20.0
# c   30.0
# d    NaN

# %%
import pandas as pd
d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']), 
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}
df = pd.DataFrame(d)
print(df.loc['b'])
# Out:
# one    2.0
# two    2.0
# Name: b, dtype: float64

# %%
import pandas as pd
df = pd.DataFrame([[1, 2], [3, 4]], columns = ['a','b'])
df2 = pd.DataFrame([[5, 6], [7, 8]], columns = ['a','b'])
df = df.append(df2)
print(df)
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 0  5  6
# 1  7  8

# %%
import pandas as pd
df = pd.DataFrame([[1, 2], [3, 4]], columns = ['a','b'])
df2 = pd.DataFrame([[5, 6], [7, 8]], columns = ['a','b'])
df = df.append(df2)
df = df.drop(0)
print(df)
# Out:
#    a  b
# 1  3  4
# 1  7  8

# %%
import pandas as pd
import numpy as np
s = pd.Series(np.random.randn(4))
print(s)
# Out:
# 0   -1.060751
# 1   -1.038323
# 2    0.099415
# 3   -0.448634
# dtype: float64

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(5,3),columns=['col1','col2','col3'])
print(df)
df.apply(np.mean)
print(df.apply(np.mean))
# Out:
#        col1      col2      col3
# 0  0.781801  3.277510 -1.319218
# 1  0.288534  0.418294  0.552427
# 2 -0.300652  0.107546 -1.087555
# 3 -0.625360  0.478775  0.388030
# 4  0.539192 -0.482916 -1.448982
# col1    0.136703
# col2    0.759842
# col3   -0.583059
# dtype: float64

# %%
import pandas as pd
import numpy as np
df1 = pd.DataFrame(np.random.randn(10,3),columns=['col1','col2','col3'])
print(df1)
df2 = pd.DataFrame(np.random.randn(7,3),columns=['col1','col2','col3'])
print(df2)
df1 = df1.reindex_like(df2)
print(df1)
# Out:
#        col1      col2      col3
# 0 -0.050478 -0.827940 -0.605261
# 1  0.237675  0.568784  2.100231
# 2  1.030993  0.905180  0.585414
# 3  0.665772  0.237585 -0.571762
# 4  0.835498 -0.697614  0.873119
# 5  0.495155  1.091169 -0.433201
# 6 -0.144316  0.156166 -0.616810
# 7 -0.586994 -0.361157 -0.357708
# 8  1.447373 -0.293108 -0.211924
# 9  0.511472 -2.348643 -0.272083
#        col1      col2      col3
# 0 -1.396425  0.646286  1.053755
# 1 -0.174774 -0.033503 -2.622780
# 2 -0.466760 -0.117421 -0.121349
# 3 -0.471064  0.298490 -1.773414
# 4  1.483934  1.181955 -0.451791
# 5  2.045071 -0.405499 -0.834521
# 6 -1.519585 -0.124244  0.937519
#        col1      col2      col3
# 0 -0.050478 -0.827940 -0.605261
# 1  0.237675  0.568784  2.100231
# 2  1.030993  0.905180  0.585414
# 3  0.665772  0.237585 -0.571762
# 4  0.835498 -0.697614  0.873119
# 5  0.495155  1.091169 -0.433201
# 6 -0.144316  0.156166 -0.616810
